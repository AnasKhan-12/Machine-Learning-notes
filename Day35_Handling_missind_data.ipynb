# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Complete Case Analysis:
#     * We remove the whole row if any value is missing from it
#     * Sirf tb kreryngy jb randomly data missing ho
#     * Agr shuru ki rows e.g starting 50 rows missing.... or end ki 50 rows missing...yan 25 shuru 25 end ma missing then
#     yay apply nhi keryingy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# MCAR Missing completely at random

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > Biggest Disadvantage
# >*  When we do CCA hmry model train hta ha all values py... so it doesnt know how to handle missing values
# ager server py deploy kerny k bad missing values ayingi to hmry model ko pta hi nhi hga inhy handle kesy kerna ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5% sy kam missing values ho tb CCA apply kerty hain zyda ho tb nahi

# %% [markdown]
# * hitograam apply kerngy numerical data py (induvidually hr column py)..before applying CCA and after applying CCA
# * Ager dono comparable ha to theek ha
