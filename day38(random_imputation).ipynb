# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# dostribution same rehta ha kuky jo values zyda hain wohi mostly pick hongi or chunky wo pick hongi to centre ma jo ubhar ha graph ha wo or brhyga to eventually distribuition shape wahi rhyga
#
# covariance is disturbed
#
# memory heavy for deployemnt
