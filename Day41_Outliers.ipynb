# %% [markdown]
# #### Outliers ko rkhna ha yn nahi A data scientist should know

# %% [markdown]
# > Like anamoly detection for transactions...... to yahan outlier rkhna paryga to detect garbar kidhr ha
#
# > But if in AGE column ksi ki age 300 mention ha to ussy to remove keryngy hi keryngy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if you want to check k outliers ka farq par rha ha yan ni to check kero if you are working on __Weight Based Algorithm__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# trimming -> outliers hata do
# capping -> certain number sy kam wlo ko certain number ma ley ao or zyda wlo ko bhi certain fix nmbr ma ly ao
# discretization (binning) -> outlier aik bin ma ajyga to outlier nhi rhyga

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# this is used when data is skewed

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Ksi bhi data per

# %% [markdown]
# ![image.png](attachment:image.png)
