# %% [markdown]
# #### Replace by any value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Mostly used in Catg. data you replace the missing value with a value  named "Missing".

# %% [markdown]
# * The whole idea is ky ap difference create kerna chah rhy ho un values ka jhan data ha un values sy jahan data nhi tha

# %% [markdown]
# * Data is not Missing at Random

# %% [markdown]
# * Not used much

# %% [markdown]
#  * Best Arbitrary Value dhoondna mushkil hta

# %% [markdown]
# ### End of Distribution Imputation
