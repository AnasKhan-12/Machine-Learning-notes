# %% [markdown]
# ### Handling Categorical Data

# %% [markdown]
# * 2 Methods
#     * Replace by most frequent value (Mode)
#     * make a new Categorical Column by the name Missing

# %% [markdown]
# numerical ma mode sy zyda acha mean/median perform kerta ha

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Changes Data distribution (Right down corner)
# * Mode should be a value that appears much more times than all other values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * if missing data is more than 5% and is around 10% or more than we dont use MODE we replace tha values with "Missing" named value so our model knows jahan jahan y value ayi ha wahan wahan data missing ha
