# %% [markdown]
# For this technique the Data should be normally distributed and show a bell curve
#
# CANNOT BE APPLIED ON SKEWED DATA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Any value outside **{mean+3sigma to mean-3sigma}** is outlier

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Here's the coding part

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("placement_odr.csv")

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 240  7.25                  38.0       0
# 127  6.95                  23.0       1
# 33   6.23                  27.0       0
# 188  5.92                  55.0       1
# 80   6.87                  46.0       1

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df['cgpa'],kde=True)

plt.subplot(1,2,2)
sns.histplot(df['placement_exam_marks'],kde=True)

plt.show()

# %%
df['placement_exam_marks'].skew()
# Out:
# np.float64(0.8356419499466834)

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323896
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %% [markdown]
# ### Applying the mean+-3sigma formula

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %% [markdown]
# ### Trimming

# %%
# Trimming
new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df
### LImit sy uper or nichy wly sb remove kerdiy or ik new dataset bna dia
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
# 998  8.62                  46.0       1
#
# [995 rows x 3 columns]

# %%
new_df.shape
# Out:
# (995, 3)

# %% [markdown]
# #### important line of code

# %%
# Approach 2

# Calculating the Zscore

df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zscore
# 0  7.19                  26.0       1     0.371425
# 1  7.46                  38.0       1     0.809810
# 2  7.54                  40.0       1     0.939701
# 3  6.42                   8.0       1    -0.878782
# 4  7.23                  17.0       0     0.436371

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
# Trimming 
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]
new_df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 513  6.43                  46.0       0    -0.862546
# 323  6.60                  38.0       0    -0.586526
# 22   6.76                  54.0       1    -0.326742
# 143  6.32                  33.0       1    -1.041147
# 212  6.23                  57.0       0    -1.187275

# %% [markdown]
# ### Caping

# %%
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
print(upper_limit)
print(lower_limit)
# Out:
# 8.808933625397168
# 5.113546374602832

# %%
df['cgpa'] = np.where(
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']<lower_limit,
        lower_limit,
        df['cgpa']
    )
)

# %%
print(df.shape)
print(df['cgpa'].describe())
# Out:
# (1000, 4)
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64
