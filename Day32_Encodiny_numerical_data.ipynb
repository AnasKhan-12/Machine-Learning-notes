# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Types of Dicretization
# ![image.png](attachment:image.png)
# >supervised binning is very rare so we'll not do that (ager kerni ha to decision tree ka knowledge hona chahiya)

# %% [markdown]
# ![image.png](attachment:image.png)
# > Bins khud decide kiay\
# > (max-min)/bins means our interval..... kitny ka aik interval hoga e,g 10 in upper case\
# > Here width of bins is equal

# %% [markdown]
# ![image.png](attachment:image.png)
# > 0 sy 16 10%\
# > (0 sy 20 20%) (16 sy 20 -> 10%)\
# > 0 sy 22 30%

# %% [markdown]
# This one is used more frequently

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# > iski 2 techniques hain:
# >* Distance of every point from centroid(triangle here)..phir jisky zyda qareeb ho us centroid wlay cluster ma chla jyga wo point
# >* Divide the whole into equal intervals .... phir jo point jisky zyda qareeb ho us centroid(cluster) ma bhjdo

# %% [markdown]
# > Nichy wali pic ma y btya ha ky har cluster ma jo centroid ha usko shift kerty hain to the mean of the values present in cluster
# >* aisa tb tk kerty hain jab tk koi change na ayay agly steps ma

# %% [markdown]
# ![image.png](attachment:image.png)
